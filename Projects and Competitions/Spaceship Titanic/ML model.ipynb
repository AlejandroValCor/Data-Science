# %%
# Imports
import pandas as pd
import numpy as np
import optuna
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score
from xgboost import XGBClassifier

# %%
# Functin for normalizing data transformation and format
def normalizeDatasetFormat(dataset):
    # Divide the passenger id, into group and member number
    passengerIdSplit = dataset['PassengerId'].str.split("_", expand=True)

    # Create new columns for group number and group member within that group
    dataset['GroupNumber'] = pd.to_numeric(passengerIdSplit[0], errors='coerce')
    dataset['GroupMember'] = pd.to_numeric(passengerIdSplit[1], errors='coerce')

    # Split the cabin variable in 3 sub sets
    cabin_split = dataset['Cabin'].str.split("/", expand=True)

    # Create new columns for each sub set of cabin
    dataset['Deck'] = cabin_split[0]
    dataset['CabinNum'] = pd.to_numeric(cabin_split[1], errors='coerce')
    dataset['Side'] = cabin_split[2]

    # Divide name in first name and last name to see if there are any insights from there.
    dataset['FirstName'], dataset['LastName'] = dataset['Name'].str.split(' ').str[0], dataset['Name'].str.split(' ').str[1]

    # Get frequency for first names and last names
    name_freq = dataset['FirstName'].value_counts()
    dataset['FirstNameFreq'] = dataset['FirstName'].map(name_freq)

    name_freq = dataset['LastName'].value_counts()
    dataset['LastNameFreq'] = dataset['LastName'].map(name_freq)

    return dataset

# %%
# Functin for normalizing boolean data transformation and format
def normalizeDatasetBoolFormat(dataset, bool_columns):
    print(dataset.head())
    
    # For dataset, map string-boolean columns to 1 for true and 0 for false, since one-hot encoding doesn't work well with 2 cardinality columns.
    for col in bool_columns:
        dataset[col] = dataset[col].map({True: 1, False: 0, 'S': 1, 'P': 0})

    print(dataset.head())

    return dataset

# %%
# Function to acquire the best parameters for XGB Regressor (Wrap function to accept parameters)
def bestParamsEstimatorXGBC(preprocessor, X_train, y_train):
    # Necessary function for optuna
    def objective(trial):
        # Declaration parameters and ranges for each one that are going to be tested with optuna
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 245, 250),
            'max_depth': trial.suggest_int('max_depth', 2, 4),
            'learning_rate': trial.suggest_float('learning_rate', 0.1, 0.2),
            #'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            #'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'random_state': 0
        }

        # Declaration of XGBR model to be used with optuna
        model = XGBClassifier(**params)

        # Pipeline creation to use with optuna
        pipeline = Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('model', model)
        ])

        # Cross validation scores acquired and mean calculated, needed for optuna to find best parameters.
        score = cross_val_score(pipeline, X_train, y_train, cv=10, scoring='accuracy') # Accuracy used because True and False values are well balanced in y_train
        return score.mean()
    
    return objective

# %%
# Importing the train and test csv files for model training and model testing.
X = pd.read_csv("D:/Archivos Personales/Courses/Data Science/Projects and Competitions/Spaceship Titanic/train.csv")
X_test_full = pd.read_csv("D:/Archivos Personales/Courses/Data Science/Projects and Competitions/Spaceship Titanic/test.csv")

# Remove rows that have Nan values in the target column.
X.dropna(axis=0, subset=['Transported'], inplace=True)

# rowsWithoutTargetValue = X[X['Transported'].isnull()] Can work as well to get empty rows for target column.

# Assign target column to Y from X dataset
Y = X.Transported
X.drop(['Transported'], axis=1, inplace=True)

# Create split dataset for training and validation
X_train_full, X_valid_full, y_train, y_valid = train_test_split(X, Y, train_size= 0.8, test_size= 0.2, random_state=0)

# %%
# Check how many Nan values per column
nanValuesPerColumn = X_train_full.isnull().sum()
nanValuesPerColumn
# Out:
# PassengerId       0
# HomePlanet      156
# CryoSleep       170
# Cabin           151
# Destination     149
# Age             146
# VIP             176
# RoomService     151
# FoodCourt       148
# ShoppingMall    172
# Spa             152
# VRDeck          146
# Name            156
# dtype: int64

# %%
# Normalize format and columns for all datasets
X_train_full = normalizeDatasetFormat(X_train_full)
X_valid_full = normalizeDatasetFormat(X_valid_full)
X_test_full = normalizeDatasetFormat(X_test_full)
X = normalizeDatasetFormat(X)

# %%
# Get categorical columns from the dataset
cat_cols = list(X_train_full.select_dtypes(include=['object']).columns)
X_train_full[cat_cols].nunique()
# Out:
# PassengerId    6954
# HomePlanet        3
# CryoSleep         2
# Cabin          5449
# Destination       3
# VIP               2
# Name           6787
# Deck              8
# Side              2
# FirstName      2557
# LastName       2123
# dtype: int64

# %%
# Remove high cardinality categorical columns
final_categorical_cols = [col for col in cat_cols if X_train_full[col].dtype == 'object' and X_train_full[col].nunique() < 16]

# Columns that can be safely ordinal encoded, verify to only use categories that were used during training.
# Needed for ordinal encoding.
#final_categorical_cols = [col for col in cat_cols if
#                    set(X_valid_full[col]).issubset(set(X_train_full[col]))]

print(final_categorical_cols)
# Out:
# ['HomePlanet', 'CryoSleep', 'Destination', 'VIP', 'Deck', 'Side']

# %%
# Get boolean columns that appear as string/object type from
bool_columns = [col for col in X_train_full.columns if X_train_full[col].dtype == 'object' and set(X_train_full[col].unique()).issubset([True, False, np.nan, 'S', 'P'])]
print(bool_columns)
# Out:
# ['CryoSleep', 'VIP', 'Side']

# %%
# Get numeric values from the dataset
final_numerical_cols = [col for col in X_train_full.columns if X_train_full[col].dtype in ['int64', 'float64']]
print(final_numerical_cols)
# Out:
# ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'GroupNumber', 'GroupMember', 'CabinNum', 'FirstNameFreq', 'LastNameFreq']

# %%
# Normalize boolean format for all datasets
X_train_full = normalizeDatasetBoolFormat(X_train_full, bool_columns)
X_valid_full = normalizeDatasetBoolFormat(X_valid_full, bool_columns)
X_test_full = normalizeDatasetBoolFormat(X_test_full, bool_columns)
X = normalizeDatasetBoolFormat(X, bool_columns)
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin  Destination   Age    VIP  \
# 4278     4558_01     Europa     False   C/167/S  55 Cancri e  54.0  False
# 5971     6326_01      Earth     False  F/1307/P  TRAPPIST-1e  20.0  False
# 464      0503_02       Mars     False    F/90/S  TRAPPIST-1e  43.0  False
# 4475     4757_01      Earth     False   F/896/S  TRAPPIST-1e  24.0  False
# 8469     9046_01     Europa      True   C/335/S  55 Cancri e  25.0  False
#
#       RoomService  FoodCourt  ShoppingMall  ...               Name  \
# 4278          0.0      559.0           0.0  ...      Wezna Baleful
# 5971          0.0       20.0           1.0  ...  Therek Hinetthews
# 464        1821.0        0.0          47.0  ...         Torms Fone
# 4475        185.0        0.0         476.0  ...    Tanley Mirandry
# 8469          0.0        0.0           0.0  ...    Alphah Cratrave
#
#       GroupNumber GroupMember  Deck  CabinNum Side  FirstName    LastName  \
# 4278         4558           1     C     167.0    S      Wezna     Baleful
# 5971         6326           1     F    1307.0    P     Therek  Hinetthews
# 464           503           2     F      90.0    S      Torms        Fone
# 4475         4757           1     F     896.0    S     Tanley    Mirandry
# 8469         9046           1     C     335.0    S     Alphah    Cratrave
#
#      FirstNameFreq LastNameFreq
# 4278           2.0          4.0
# 5971           5.0          6.0
# 464            2.0          9.0
# 4475           4.0          3.0
# 8469           7.0          3.0
#
# [5 rows x 22 columns]
#      PassengerId HomePlanet  CryoSleep     Cabin  Destination   Age  VIP  \
# 4278     4558_01     Europa        0.0   C/167/S  55 Cancri e  54.0  0.0
# 5971     6326_01      Earth        0.0  F/1307/P  TRAPPIST-1e  20.0  0.0
# 464      0503_02       Mars        0.0    F/90/S  TRAPPIST-1e  43.0  0.0
# 4475     4757_01      Earth        0.0   F/896/S  TRAPPIST-1e  24.0  0.0
# 8469     9046_01     Europa        1.0   C/335/S  55 Cancri e  25.0  0.0
#
#       RoomService  FoodCourt  ShoppingMall  ...               Name  \
# 4278          0.0      559.0           0.0  ...      Wezna Baleful
# 5971          0.0       20.0           1.0  ...  Therek Hinetthews
# 464        1821.0        0.0          47.0  ...         Torms Fone
# 4475        185.0        0.0         476.0  ...    Tanley Mirandry
# 8469          0.0        0.0           0.0  ...    Alphah Cratrave
#
#       GroupNumber GroupMember  Deck  CabinNum Side  FirstName    LastName  \
# 4278         4558           1     C     167.0  1.0      Wezna     Baleful
# 5971         6326           1     F    1307.0  0.0     Therek  Hinetthews
# 464           503           2     F      90.0  1.0      Torms        Fone
# 4475         4757           1     F     896.0  1.0     Tanley    Mirandry
# 8469         9046           1     C     335.0  1.0     Alphah    Cratrave
#
#      FirstNameFreq LastNameFreq
# 4278           2.0          4.0
# 5971           5.0          6.0
# 464            2.0          9.0
# 4475           4.0          3.0
# 8469           7.0          3.0
#
# [5 rows x 22 columns]
#      PassengerId HomePlanet CryoSleep     Cabin  Destination   Age    VIP  \
# 3601     3868_05      Earth     False   F/731/S  55 Cancri e  16.0  False
# 6057     6405_02      Earth       NaN       NaN          NaN   2.0  False
# 2797     3021_01      Earth     False   G/476/S  TRAPPIST-1e  31.0  False
# 7110     7578_01      Earth     False  F/1572/P  55 Cancri e  14.0  False
# 8579     9158_01     Europa      True   B/298/P  55 Cancri e  30.0   True
#
#       RoomService  FoodCourt  ShoppingMall  ...               Name  \
# 3601          0.0        0.0         623.0  ...      Darry Braymon
# 6057          0.0        0.0           0.0  ...   Feline Toddleton
# 2797        517.0        1.0         301.0  ...  Deanny Spencervan
# 7110        653.0        0.0           4.0  ...   Idace Popelacruz
# 8579          0.0        0.0           0.0  ...    Magnon Maglible
#
#       GroupNumber GroupMember  Deck  CabinNum Side  FirstName    LastName  \
# 3601         3868           5     F     731.0    S      Darry     Braymon
# 6057         6405           2   NaN       NaN  NaN     Feline   Toddleton
# 2797         3021           1     G     476.0    S     Deanny  Spencervan
# 7110         7578           1     F    1572.0    P      Idace  Popelacruz
# 8579         9158           1     B     298.0    P     Magnon    Maglible
#
#      FirstNameFreq LastNameFreq
# 3601           1.0          1.0
# 6057           2.0          3.0
# 2797           3.0          1.0
# 7110           5.0          1.0
# 8579           1.0          1.0
#
# [5 rows x 22 columns]
#      PassengerId HomePlanet  CryoSleep     Cabin  Destination   Age  VIP  \
# 3601     3868_05      Earth        0.0   F/731/S  55 Cancri e  16.0  0.0
# 6057     6405_02      Earth        NaN       NaN          NaN   2.0  0.0
# 2797     3021_01      Earth        0.0   G/476/S  TRAPPIST-1e  31.0  0.0
# 7110     7578_01      Earth        0.0  F/1572/P  55 Cancri e  14.0  0.0
# 8579     9158_01     Europa        1.0   B/298/P  55 Cancri e  30.0  1.0
#
#       RoomService  FoodCourt  ShoppingMall  ...               Name  \
# 3601          0.0        0.0         623.0  ...      Darry Braymon
# 6057          0.0        0.0           0.0  ...   Feline Toddleton
# 2797        517.0        1.0         301.0  ...  Deanny Spencervan
# 7110        653.0        0.0           4.0  ...   Idace Popelacruz
# 8579          0.0        0.0           0.0  ...    Magnon Maglible
#
#       GroupNumber GroupMember  Deck  CabinNum Side  FirstName    LastName  \
# 3601         3868           5     F     731.0  1.0      Darry     Braymon
# 6057         6405           2   NaN       NaN  NaN     Feline   Toddleton
# 2797         3021           1     G     476.0  1.0     Deanny  Spencervan
# 7110         7578           1     F    1572.0  0.0      Idace  Popelacruz
# 8579         9158           1     B     298.0  0.0     Magnon    Maglible
#
#      FirstNameFreq LastNameFreq
# 3601           1.0          1.0
# 6057           2.0          3.0
# 2797           3.0          1.0
# 7110           5.0          1.0
# 8579           1.0          1.0
#
# [5 rows x 22 columns]
#   PassengerId HomePlanet CryoSleep  Cabin  Destination   Age    VIP  \
# 0     0013_01      Earth      True  G/3/S  TRAPPIST-1e  27.0  False
# 1     0018_01      Earth     False  F/4/S  TRAPPIST-1e  19.0  False
# 2     0019_01     Europa      True  C/0/S  55 Cancri e  31.0  False
# 3     0021_01     Europa     False  C/1/S  TRAPPIST-1e  38.0  False
# 4     0023_01      Earth     False  F/5/S  TRAPPIST-1e  20.0  False
#
#    RoomService  FoodCourt  ShoppingMall  ...              Name  GroupNumber  \
# 0          0.0        0.0           0.0  ...   Nelly Carsoning           13
# 1          0.0        9.0           0.0  ...    Lerome Peckers           18
# 2          0.0        0.0           0.0  ...   Sabih Unhearfus           19
# 3          0.0     6652.0           0.0  ...  Meratz Caltilter           21
# 4         10.0        0.0         635.0  ...   Brence Harperez           23
#
#   GroupMember  Deck  CabinNum Side  FirstName   LastName FirstNameFreq  \
# 0           1     G       3.0    S      Nelly  Carsoning           3.0
# 1           1     F       4.0    S     Lerome    Peckers           3.0
# 2           1     C       0.0    S      Sabih  Unhearfus           2.0
# 3           1     C       1.0    S     Meratz  Caltilter           2.0
# 4           1     F       5.0    S     Brence   Harperez           3.0
#
#   LastNameFreq
# 0          4.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          3.0
#
# [5 rows x 22 columns]
#   PassengerId HomePlanet  CryoSleep  Cabin  Destination   Age  VIP  \
# 0     0013_01      Earth        1.0  G/3/S  TRAPPIST-1e  27.0  0.0
# 1     0018_01      Earth        0.0  F/4/S  TRAPPIST-1e  19.0  0.0
# 2     0019_01     Europa        1.0  C/0/S  55 Cancri e  31.0  0.0
# 3     0021_01     Europa        0.0  C/1/S  TRAPPIST-1e  38.0  0.0
# 4     0023_01      Earth        0.0  F/5/S  TRAPPIST-1e  20.0  0.0
#
#    RoomService  FoodCourt  ShoppingMall  ...              Name  GroupNumber  \
# 0          0.0        0.0           0.0  ...   Nelly Carsoning           13
# 1          0.0        9.0           0.0  ...    Lerome Peckers           18
# 2          0.0        0.0           0.0  ...   Sabih Unhearfus           19
# 3          0.0     6652.0           0.0  ...  Meratz Caltilter           21
# 4         10.0        0.0         635.0  ...   Brence Harperez           23
#
#   GroupMember  Deck  CabinNum Side  FirstName   LastName FirstNameFreq  \
# 0           1     G       3.0  1.0      Nelly  Carsoning           3.0
# 1           1     F       4.0  1.0     Lerome    Peckers           3.0
# 2           1     C       0.0  1.0      Sabih  Unhearfus           2.0
# 3           1     C       1.0  1.0     Meratz  Caltilter           2.0
# 4           1     F       5.0  1.0     Brence   Harperez           3.0
#
#   LastNameFreq
# 0          4.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          3.0
#
# [5 rows x 22 columns]
#   PassengerId HomePlanet CryoSleep  Cabin  Destination   Age    VIP  \
# 0     0001_01     Europa     False  B/0/P  TRAPPIST-1e  39.0  False
# 1     0002_01      Earth     False  F/0/S  TRAPPIST-1e  24.0  False
# 2     0003_01     Europa     False  A/0/S  TRAPPIST-1e  58.0   True
# 3     0003_02     Europa     False  A/0/S  TRAPPIST-1e  33.0  False
# 4     0004_01      Earth     False  F/1/S  TRAPPIST-1e  16.0  False
#
#    RoomService  FoodCourt  ShoppingMall  ...               Name  GroupNumber  \
# 0          0.0        0.0           0.0  ...    Maham Ofracculy            1
# 1        109.0        9.0          25.0  ...       Juanna Vines            2
# 2         43.0     3576.0           0.0  ...      Altark Susent            3
# 3          0.0     1283.0         371.0  ...       Solam Susent            3
# 4        303.0       70.0         151.0  ...  Willy Santantines            4
#
#   GroupMember  Deck  CabinNum Side  FirstName     LastName FirstNameFreq  \
# 0           1     B       0.0    P      Maham    Ofracculy           4.0
# 1           1     F       0.0    S     Juanna        Vines           6.0
# 2           1     A       0.0    S     Altark       Susent           1.0
# 3           2     A       0.0    S      Solam       Susent           3.0
# 4           1     F       1.0    S      Willy  Santantines           9.0
#
#   LastNameFreq
# 0          1.0
# 1          4.0
# 2          6.0
# 3          6.0
# 4          6.0
#
# [5 rows x 22 columns]
#   PassengerId HomePlanet  CryoSleep  Cabin  Destination   Age  VIP  \
# 0     0001_01     Europa        0.0  B/0/P  TRAPPIST-1e  39.0  0.0
# 1     0002_01      Earth        0.0  F/0/S  TRAPPIST-1e  24.0  0.0
# 2     0003_01     Europa        0.0  A/0/S  TRAPPIST-1e  58.0  1.0
# 3     0003_02     Europa        0.0  A/0/S  TRAPPIST-1e  33.0  0.0
# 4     0004_01      Earth        0.0  F/1/S  TRAPPIST-1e  16.0  0.0
#
#    RoomService  FoodCourt  ShoppingMall  ...               Name  GroupNumber  \
# 0          0.0        0.0           0.0  ...    Maham Ofracculy            1
# 1        109.0        9.0          25.0  ...       Juanna Vines            2
# 2         43.0     3576.0           0.0  ...      Altark Susent            3
# 3          0.0     1283.0         371.0  ...       Solam Susent            3
# 4        303.0       70.0         151.0  ...  Willy Santantines            4
#
#   GroupMember  Deck  CabinNum Side  FirstName     LastName FirstNameFreq  \
# 0           1     B       0.0  0.0      Maham    Ofracculy           4.0
# 1           1     F       0.0  1.0     Juanna        Vines           6.0
# 2           1     A       0.0  1.0     Altark       Susent           1.0
# 3           2     A       0.0  1.0      Solam       Susent           3.0
# 4           1     F       1.0  1.0      Willy  Santantines           9.0
#
#   LastNameFreq
# 0          1.0
# 1          4.0
# 2          6.0
# 3          6.0
# 4          6.0
#
# [5 rows x 22 columns]

# %%
# Normalize all dataset to have the same columns and format

final_categorical_cols = [col for col in final_categorical_cols if col not in bool_columns] # Since we know boolean is recognized as string and to avoid duplicates.
my_columns = final_categorical_cols + bool_columns + final_numerical_cols

X_train = X_train_full[my_columns].copy()
X_valid = X_valid_full[my_columns].copy()
X_test = X_test_full[my_columns].copy()
X = X[my_columns].copy()

# %%
#------------------------------------------------Pipeline creation----------------------------------------------------

# Preprocessing for numerical columns
numerical_transformer = SimpleImputer(strategy='most_frequent')

# Preprocessing for boolean columns
boolean_transformer = SimpleImputer(strategy='mean')

# Preprocessing for categorical columns
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('OneHotEnc', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    #('ordEnc', OrdinalEncoder())
])

# Bundles numerical and categorical preprocessing
preprocessor = ColumnTransformer(transformers=[
    ('numerical', numerical_transformer, final_numerical_cols),
    ('boolean', boolean_transformer, bool_columns),
    ('categorical', categorical_transformer, final_categorical_cols)
])

# Study creation and optimization process to find best parameters with optuna
study = optuna.create_study(direction='maximize')
study.optimize(bestParamsEstimatorXGBC(preprocessor, X_train, y_train), n_trials=100)

print("Best parameters found:", study.best_params)
# Out:
# [I 2025-04-24 01:57:18,545] A new study created in memory with name: no-name-bd7d7188-4788-4ad7-bc17-1766c1089884
# [I 2025-04-24 01:57:22,194] Trial 0 finished with value: 0.8065899694037875 and parameters: {'n_estimators': 245, 'max_depth': 2, 'learning_rate': 0.1491709265735252}. Best is trial 0 with value: 0.8065899694037875.
# [I 2025-04-24 01:57:25,688] Trial 1 finished with value: 0.8035708674439757 and parameters: {'n_estimators': 250, 'max_depth': 2, 'learning_rate': 0.1053701529958789}. Best is trial 0 with value: 0.8065899694037875.
# [I 2025-04-24 01:57:28,997] Trial 2 finished with value: 0.805152154138758 and parameters: {'n_estimators': 245, 'max_depth': 2, 'learning_rate': 0.18742272932764506}. Best is trial 0 with value: 0.8065899694037875.
# [I 2025-04-24 01:57:34,096] Trial 3 finished with value: 0.809177209956173 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.1695819877066976}. Best is trial 3 with value: 0.809177209956173.
# [I 2025-04-24 01:57:38,795] Trial 4 finished with value: 0.8097515091375176 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.13814583420697008}. Best is trial 4 with value: 0.8097515091375176.
# [I 2025-04-24 01:57:43,599] Trial 5 finished with value: 0.8129173902257504 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.10440682800322576}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:57:48,472] Trial 6 finished with value: 0.8086016703878277 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.18174745163886613}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:57:53,462] Trial 7 finished with value: 0.8054376498800959 and parameters: {'n_estimators': 249, 'max_depth': 4, 'learning_rate': 0.18559164133712358}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:57:58,334] Trial 8 finished with value: 0.8091774166873398 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.16655637908774748}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:01,494] Trial 9 finished with value: 0.8040027288514017 and parameters: {'n_estimators': 250, 'max_depth': 2, 'learning_rate': 0.1634816030264409}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:05,678] Trial 10 finished with value: 0.8077414620028115 and parameters: {'n_estimators': 248, 'max_depth': 3, 'learning_rate': 0.10468671491175494}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:09,526] Trial 11 finished with value: 0.8081729099479038 and parameters: {'n_estimators': 246, 'max_depth': 3, 'learning_rate': 0.12888701067272446}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:13,663] Trial 12 finished with value: 0.8103293227486976 and parameters: {'n_estimators': 246, 'max_depth': 3, 'learning_rate': 0.12952696216140172}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:17,633] Trial 13 finished with value: 0.807308360208385 and parameters: {'n_estimators': 246, 'max_depth': 3, 'learning_rate': 0.12013450839209014}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:21,743] Trial 14 finished with value: 0.8090355991069214 and parameters: {'n_estimators': 246, 'max_depth': 3, 'learning_rate': 0.1236171253777472}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:25,740] Trial 15 finished with value: 0.8081731166790705 and parameters: {'n_estimators': 248, 'max_depth': 3, 'learning_rate': 0.11271476321840017}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:29,671] Trial 16 finished with value: 0.8071644753162988 and parameters: {'n_estimators': 247, 'max_depth': 3, 'learning_rate': 0.1389909449929151}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:34,368] Trial 17 finished with value: 0.8109042421235426 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.10237338252245495}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:39,096] Trial 18 finished with value: 0.8091778301496733 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.10020686519067336}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:43,893] Trial 19 finished with value: 0.8067336475647068 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.19812371269457674}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:48,618] Trial 20 finished with value: 0.808889646903167 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.11412737360163797}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:52,766] Trial 21 finished with value: 0.8106183329198708 and parameters: {'n_estimators': 246, 'max_depth': 3, 'learning_rate': 0.13235219503191314}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:58:57,811] Trial 22 finished with value: 0.8126292069792443 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.11084268955903524}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:02,553] Trial 23 finished with value: 0.8120555279914001 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.11269286354282157}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:07,231] Trial 24 finished with value: 0.8091786570743406 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.11329066646932807}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:12,125] Trial 25 finished with value: 0.8100425866203589 and parameters: {'n_estimators': 249, 'max_depth': 4, 'learning_rate': 0.12073004972382138}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:16,822] Trial 26 finished with value: 0.807164888778632 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.14697230506030276}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:21,559] Trial 27 finished with value: 0.8106181261887041 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.11175571173406712}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:26,383] Trial 28 finished with value: 0.8127728851401637 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.10859152097907049}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:31,190] Trial 29 finished with value: 0.8083145207971555 and parameters: {'n_estimators': 249, 'max_depth': 4, 'learning_rate': 0.15850826842328927}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:36,005] Trial 30 finished with value: 0.8086039444306623 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.15110553360892726}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:40,846] Trial 31 finished with value: 0.8117658976267264 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.10730711237969016}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:45,628] Trial 32 finished with value: 0.8117675514760606 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.1182403368448732}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:50,576] Trial 33 finished with value: 0.8073071198213843 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.10708113357470538}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:55,562] Trial 34 finished with value: 0.8107630447366245 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10940992135816457}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 01:59:58,886] Trial 35 finished with value: 0.8041445464318201 and parameters: {'n_estimators': 247, 'max_depth': 2, 'learning_rate': 0.125521284075085}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:03,856] Trial 36 finished with value: 0.809896220954271 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.1005444511449456}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:08,671] Trial 37 finished with value: 0.8087470023980815 and parameters: {'n_estimators': 249, 'max_depth': 4, 'learning_rate': 0.11689092359569841}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:13,615] Trial 38 finished with value: 0.8075971636483915 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.1352214288502786}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:18,337] Trial 39 finished with value: 0.8057272802447697 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.17411703877123477}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:22,424] Trial 40 finished with value: 0.8065920367154551 and parameters: {'n_estimators': 245, 'max_depth': 3, 'learning_rate': 0.10728139482232256}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:27,208] Trial 41 finished with value: 0.8087463822045811 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.11819403526533123}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:32,011] Trial 42 finished with value: 0.809753162986852 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.11613105555079199}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:37,067] Trial 43 finished with value: 0.8110468866286281 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.1255576170390052}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:41,857] Trial 44 finished with value: 0.8104717605226164 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.1045974728914667}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:46,605] Trial 45 finished with value: 0.8104719672537831 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.12219333387073163}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:49,936] Trial 46 finished with value: 0.8028506160588771 and parameters: {'n_estimators': 250, 'max_depth': 2, 'learning_rate': 0.11013228185756416}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:54,876] Trial 47 finished with value: 0.8123395766145706 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.14012384749816376}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:00:58,871] Trial 48 finished with value: 0.8068771189944595 and parameters: {'n_estimators': 246, 'max_depth': 3, 'learning_rate': 0.1467111310540449}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:03,695] Trial 49 finished with value: 0.8073071198213844 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.14218257102436968}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:07,677] Trial 50 finished with value: 0.8070210038865457 and parameters: {'n_estimators': 247, 'max_depth': 3, 'learning_rate': 0.1562684634043324}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:12,376] Trial 51 finished with value: 0.8113354833374679 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.1278060231185352}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:17,101] Trial 52 finished with value: 0.8107607706937898 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.10471402484179754}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:21,829] Trial 53 finished with value: 0.8114787480360539 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.11673521496666109}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:26,719] Trial 54 finished with value: 0.808460059538576 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.13215478214379592}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:31,491] Trial 55 finished with value: 0.8090351856445878 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.11142681177215573}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:36,266] Trial 56 finished with value: 0.8117648639708921 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.1031255575774833}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:41,015] Trial 57 finished with value: 0.8117677582072271 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.11436272192216537}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:45,751] Trial 58 finished with value: 0.8121975523029852 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.1225230483214357}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:49,766] Trial 59 finished with value: 0.8058715785991895 and parameters: {'n_estimators': 246, 'max_depth': 3, 'learning_rate': 0.14131241819956095}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:54,692] Trial 60 finished with value: 0.8091788638055073 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.12303810668656834}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:01:59,479] Trial 61 finished with value: 0.810471140329116 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.11444526954110809}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:04,257] Trial 62 finished with value: 0.8106146117588688 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.10920348206587467}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:09,033] Trial 63 finished with value: 0.8103295294798645 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.1201369661684904}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:14,019] Trial 64 finished with value: 0.8093219217729264 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.11381606385196388}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:18,726] Trial 65 finished with value: 0.8120544943355661 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10656763599646982}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:23,537] Trial 66 finished with value: 0.8093217150417595 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10037361062522929}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:28,277] Trial 67 finished with value: 0.8083136938724882 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10415443853474517}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:33,067] Trial 68 finished with value: 0.8121977590341519 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10822984559050886}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:37,809] Trial 69 finished with value: 0.8061581079963617 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.10911223625859702}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:42,539] Trial 70 finished with value: 0.8074512114446375 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.12951129606180237}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:47,311] Trial 71 finished with value: 0.8088910940213347 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.11142155531379314}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:52,182] Trial 72 finished with value: 0.8119095757876457 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10594058552865492}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:02:56,914] Trial 73 finished with value: 0.8123414371950715 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10216178033237329}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:01,760] Trial 74 finished with value: 0.807740014884644 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10223364529005152}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:06,589] Trial 75 finished with value: 0.8083145207971555 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.1077207190393228}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:11,335] Trial 76 finished with value: 0.8100407260398578 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10248166241108257}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:16,083] Trial 77 finished with value: 0.8109040353923757 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.11826007860288103}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:20,925] Trial 78 finished with value: 0.8106160588770364 and parameters: {'n_estimators': 249, 'max_depth': 4, 'learning_rate': 0.11210951431608174}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:25,693] Trial 79 finished with value: 0.8047207061936656 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.19911237340620042}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:30,493] Trial 80 finished with value: 0.8080269577441495 and parameters: {'n_estimators': 248, 'max_depth': 4, 'learning_rate': 0.10005147716037217}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:35,348] Trial 81 finished with value: 0.810040519308691 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.1067940665628925}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:40,048] Trial 82 finished with value: 0.8087478293227486 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10940216150051116}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:44,923] Trial 83 finished with value: 0.8107570495327876 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10555392829292201}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:49,779] Trial 84 finished with value: 0.8124855288183246 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.120567279216678}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:54,700] Trial 85 finished with value: 0.8068789795749607 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.1267929895509957}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:03:59,392] Trial 86 finished with value: 0.8094655999338458 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.12126764951532248}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:04:04,348] Trial 87 finished with value: 0.8075969569172248 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.13266316497671748}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:04:07,844] Trial 88 finished with value: 0.8047215331183329 and parameters: {'n_estimators': 246, 'max_depth': 2, 'learning_rate': 0.12458643374123862}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:04:12,607] Trial 89 finished with value: 0.8104727941784503 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.11540303107242643}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:04:16,649] Trial 90 finished with value: 0.8083155544529893 and parameters: {'n_estimators': 248, 'max_depth': 3, 'learning_rate': 0.17228016650868727}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:04:21,493] Trial 91 finished with value: 0.8100392789216901 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.11865262853584721}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:04:26,142] Trial 92 finished with value: 0.8081702224427355 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.11120054871496307}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:04:31,030] Trial 93 finished with value: 0.808313073678988 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.18988750592161785}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:04:36,162] Trial 94 finished with value: 0.8084596460762425 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.10277503993748387}. Best is trial 5 with value: 0.8129173902257504.
# [I 2025-04-24 02:04:41,114] Trial 95 finished with value: 0.8132022657735881 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.10800468137384807}. Best is trial 95 with value: 0.8132022657735881.
# [I 2025-04-24 02:04:46,049] Trial 96 finished with value: 0.8107591168444553 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.11326044564548543}. Best is trial 95 with value: 0.8132022657735881.
# [I 2025-04-24 02:04:50,952] Trial 97 finished with value: 0.810471140329116 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.1083295786670252}. Best is trial 95 with value: 0.8132022657735881.
# [I 2025-04-24 02:04:56,006] Trial 98 finished with value: 0.8114779211113868 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.13658304964739984}. Best is trial 95 with value: 0.8132022657735881.
# [I 2025-04-24 02:05:00,646] Trial 99 finished with value: 0.8087467956669148 and parameters: {'n_estimators': 247, 'max_depth': 4, 'learning_rate': 0.11715152279386332}. Best is trial 95 with value: 0.8132022657735881.
# Best parameters found: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.10800468137384807}

# %%
# Creation of XGBRegressor with the best parameters found by optuna
model = XGBClassifier(
    n_estimators = study.best_params['n_estimators'],
    max_depth = study.best_params['max_depth'],
    learning_rate = study.best_params['learning_rate'],
    #subsample = study.best_params['subsample'],
    #colsample_bytree = study.best_params['colsample_bytree']
    )

# Pipeline creation with model with best parameters
regressor = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', model)
])

# Fitting and training model with train dataset
regressor.fit(X_train, y_train)

# Get predictions for valid dataset with random forest regressor model
predictions = regressor.predict(X_valid)

# %%
# Get accuracy and precision values for the model
# Accuracy and precision only work for classification models.
accuracy = accuracy_score(y_valid, predictions)
precision = precision_score(y_valid, predictions)

# Print accuracy and precision values for the model
print(f"Accuracy: {accuracy*100:.2f}%")
print(f"Precision: {precision*100:.2f}%")

# Print MAE value for the model
print("MAE: ", mean_absolute_error(y_valid, predictions))
# Out:
# Accuracy: 80.39%
# Precision: 78.92%
# MAE:  0.1960897067280046

# %%
# Apply preprocessing pipeline to the datasets
X_train_processed = preprocessor.fit_transform(X_train)
X_valid_processed = preprocessor.transform(X_valid)

#print(pd.DataFrame(X_train_processed, columns=preprocessor.get_feature_names_out())) Useful for visualizing post tranformation
 
# Model creation and training for training X_train data
validationModel = XGBClassifier(n_estimators = 200, early_stopping_rounds = 20, learning_rate=0.1, n_jobs=4, verbosity=1, eval_metric='logloss') # eval_metric='logloss' only used in classifier.

validationModel.fit(X_train_processed, y_train,
          eval_set=[(X_valid_processed, y_valid)])

# Preprocessing of validation data to get predictions
predictions = validationModel.predict(X_valid_processed)
# Out:
# [0]	validation_0-logloss:0.65391
# [1]	validation_0-logloss:0.62110
# [2]	validation_0-logloss:0.59333
# [3]	validation_0-logloss:0.57068
# [4]	validation_0-logloss:0.55113
# [5]	validation_0-logloss:0.53437
# [6]	validation_0-logloss:0.51986
# [7]	validation_0-logloss:0.50756
# [8]	validation_0-logloss:0.49682
# [9]	validation_0-logloss:0.48758
# [10]	validation_0-logloss:0.47911
# [11]	validation_0-logloss:0.47246
# [12]	validation_0-logloss:0.46567
# [13]	validation_0-logloss:0.45977
# [14]	validation_0-logloss:0.45453
# [15]	validation_0-logloss:0.44946
# [16]	validation_0-logloss:0.44499
# [17]	validation_0-logloss:0.44072
# [18]	validation_0-logloss:0.43786
# [19]	validation_0-logloss:0.43208
# [20]	validation_0-logloss:0.42858
# [21]	validation_0-logloss:0.42641
# [22]	validation_0-logloss:0.42386
# [23]	validation_0-logloss:0.42170
# [24]	validation_0-logloss:0.41943
# [25]	validation_0-logloss:0.41687
# [26]	validation_0-logloss:0.41545
# [27]	validation_0-logloss:0.41424
# [28]	validation_0-logloss:0.41320
# [29]	validation_0-logloss:0.41177
# [30]	validation_0-logloss:0.40955
# [31]	validation_0-logloss:0.40749
# [32]	validation_0-logloss:0.40625
# [33]	validation_0-logloss:0.40537
# [34]	validation_0-logloss:0.40403
# [35]	validation_0-logloss:0.40357
# [36]	validation_0-logloss:0.40261
# [37]	validation_0-logloss:0.40214
# [38]	validation_0-logloss:0.40129
# [39]	validation_0-logloss:0.40000
# [40]	validation_0-logloss:0.39947
# [41]	validation_0-logloss:0.39866
# [42]	validation_0-logloss:0.39828
# [43]	validation_0-logloss:0.39768
# [44]	validation_0-logloss:0.39753
# [45]	validation_0-logloss:0.39692
# [46]	validation_0-logloss:0.39738
# [47]	validation_0-logloss:0.39736
# [48]	validation_0-logloss:0.39752
# [49]	validation_0-logloss:0.39711
# [50]	validation_0-logloss:0.39664
# [51]	validation_0-logloss:0.39621
# [52]	validation_0-logloss:0.39564
# [53]	validation_0-logloss:0.39499
# [54]	validation_0-logloss:0.39485
# [55]	validation_0-logloss:0.39468
# [56]	validation_0-logloss:0.39467
# [57]	validation_0-logloss:0.39398
# [58]	validation_0-logloss:0.39402
# [59]	validation_0-logloss:0.39440
# [60]	validation_0-logloss:0.39383
# [61]	validation_0-logloss:0.39351
# [62]	validation_0-logloss:0.39315
# [63]	validation_0-logloss:0.39297
# [64]	validation_0-logloss:0.39323
# [65]	validation_0-logloss:0.39307
# [66]	validation_0-logloss:0.39280
# [67]	validation_0-logloss:0.39315
# [68]	validation_0-logloss:0.39315
# [69]	validation_0-logloss:0.39327
# [70]	validation_0-logloss:0.39363
# [71]	validation_0-logloss:0.39321
# [72]	validation_0-logloss:0.39263
# [73]	validation_0-logloss:0.39243
# [74]	validation_0-logloss:0.39234
# [75]	validation_0-logloss:0.39235
# [76]	validation_0-logloss:0.39219
# [77]	validation_0-logloss:0.39188
# [78]	validation_0-logloss:0.39175
# [79]	validation_0-logloss:0.39164
# [80]	validation_0-logloss:0.39163
# [81]	validation_0-logloss:0.39154
# [82]	validation_0-logloss:0.39093
# [83]	validation_0-logloss:0.39112
# [84]	validation_0-logloss:0.39105
# [85]	validation_0-logloss:0.39092
# [86]	validation_0-logloss:0.39094
# [87]	validation_0-logloss:0.39077
# [88]	validation_0-logloss:0.39047
# [89]	validation_0-logloss:0.39079
# [90]	validation_0-logloss:0.39094
# [91]	validation_0-logloss:0.39104
# [92]	validation_0-logloss:0.39081
# [93]	validation_0-logloss:0.39088
# [94]	validation_0-logloss:0.39087
# [95]	validation_0-logloss:0.39118
# [96]	validation_0-logloss:0.39123
# [97]	validation_0-logloss:0.39116
# [98]	validation_0-logloss:0.39086
# [99]	validation_0-logloss:0.39072
# [100]	validation_0-logloss:0.39075
# [101]	validation_0-logloss:0.39071
# [102]	validation_0-logloss:0.39072
# [103]	validation_0-logloss:0.39069
# [104]	validation_0-logloss:0.39083
# [105]	validation_0-logloss:0.39069
# [106]	validation_0-logloss:0.39062
# [107]	validation_0-logloss:0.39051
# [108]	validation_0-logloss:0.39032
# [109]	validation_0-logloss:0.39040
# [110]	validation_0-logloss:0.39042
# [111]	validation_0-logloss:0.39034
# [112]	validation_0-logloss:0.39079
# [113]	validation_0-logloss:0.39096
# [114]	validation_0-logloss:0.39078
# [115]	validation_0-logloss:0.39064
# [116]	validation_0-logloss:0.39077
# [117]	validation_0-logloss:0.39072
# [118]	validation_0-logloss:0.39063
# [119]	validation_0-logloss:0.39066
# [120]	validation_0-logloss:0.39070
# [121]	validation_0-logloss:0.39041
# [122]	validation_0-logloss:0.39094
# [123]	validation_0-logloss:0.39111
# [124]	validation_0-logloss:0.39096
# [125]	validation_0-logloss:0.39115
# [126]	validation_0-logloss:0.39114
# [127]	validation_0-logloss:0.39138

# %%
# Get accuracy and precision values for the model
# Accuracy and precision only work for classification models.
accuracy = accuracy_score(y_valid, predictions)
precision = precision_score(y_valid, predictions)

# Print accuracy and precision values for the model
print(f"Accuracy: {accuracy*100:.2f}%")
print(f"Precision: {precision*100:.2f}%")

# Print MAE value for the model
print("MAE: ", mean_absolute_error(y_valid, predictions))
# Out:
# Accuracy: 81.02%
# Precision: 79.42%
# MAE:  0.18976423231742381

# %%
# Final training with whole X and Y datasets
#------------------------------------------------Pipeline creation----------------------------------------------------

# For the final model training and prediction after validation and tweaking
X_processed = preprocessor.fit_transform(X)
X_test_processed = preprocessor.transform(X_test)

# Model creation model.best_iteration + 1
finalModel = XGBClassifier(n_estimators = validationModel.best_iteration + 1, learning_rate=0.1, n_jobs=4, verbosity=1, eval_metric='logloss')

# Final model fitting and training with whole dataset
finalModel.fit(X_processed, Y)

# Preprocessing of validation data to get predictions
predictions = finalModel.predict(X_test_processed)

# Change predictions to boolean format
boolPredictions = predictions.astype(bool)

# %%
# Save predictions in the format used for competition scoring
output = pd.DataFrame({'PassengerId': X_test_full.PassengerId,
                       'Transported': boolPredictions})
output.to_csv('submission.csv', index=False)
